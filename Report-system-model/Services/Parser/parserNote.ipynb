# %% [markdown]
# Библиотеки и подключение к БД

# %%
import tkinter as tk
from tkinter import filedialog
import openpyxl
import pandas as pd
import psycopg2
from psycopg2 import sql
import tkinter as tk
from tkinter import messagebox
from sqlalchemy import create_engine

unique_values = []
conn = psycopg2.connect(
        host="localhost",
        database="rsm",
        user="postgres",
        password="postgres"
    )

# %% [markdown]
# Заполнение таблиц с единственным атрибутом-ключом

# %%
file_path = 'singleTablesFilling.xlsx'
excel_file = file_path
df = pd.read_excel(excel_file)

# Выбор необходимого столбца
workbook = openpyxl.load_workbook(excel_file)
sheet = workbook.active
row_number = 1
max_col = sheet.max_column
table_name = ''
try:
    # Проходимся по всем столбцам
    for col_num in range(1, max_col + 1):
        # Получаем буквенное представление номера столбца (A, B, C, ..., AA, AB, ...)
        col_letter = openpyxl.utils.get_column_letter(col_num)

        # Снова неизменяемая часть не считая названия столбца в sql-запросе
        cell_value = sheet[f'{col_letter}{row_number}'].value
        print(f'Текст из ячейки {col_letter}{row_number}: {cell_value}')

        # Выберите столбец, в котором нужно найти уникальные строки
        column = cell_value
        cleaned_column = df[column].dropna()

        # Получить уникальные значения из очищенного столбца и преобразовать их в список
        unique_values = cleaned_column.drop_duplicates().tolist()

        # Вывести уникальные значения без пустых ячеек
        print(unique_values)

        # Получаем значение из ячейки (например, из ячейки A1)
        cell = f'{col_letter}1'
        cell_value = sheet[cell].value

        # Создаем строку с текстом из ячейки
        table_name = str(cell_value)
        # Создание курсора
        cur = conn.cursor()
        # Список значений, которые вы хотите добавить
        values = unique_values

        # Название столбца, который вы хотите проверить
        column_name = "value"
        cursor = conn.cursor()
        query = f"SELECT EXISTS (SELECT 1 FROM information_schema.columns WHERE table_name = '{table_name}' AND column_name = '{column_name}')"
        cursor.execute(query)
        column_exists = cursor.fetchone()[0]

        if column_exists:
            sql = f"INSERT INTO {table_name} (value) VALUES (%s)"
            # Использование цикла для добавления каждого значения в базу данных
            for значение in values:
                cur.execute(sql, (значение,))
            conn.commit()

        else:
            sql = f"INSERT INTO {table_name} (title) VALUES (%s)"
            # Использование цикла для добавления каждого значения в базу данных
            for значение in values:
                cur.execute(sql, (значение,))
            conn.commit()

        print(table_name, 'заполнилась успешно')

except:
    print(table_name, 'не заполнилась')

finally:
    print('Конец выполнения')
# Out:
# Текст из ячейки A1: company
# ['ЛУКОЙЛ-ПЕРМЬ', 'ЛУКОЙЛ-Нижневолжскнефть', 'ЛУКОЙЛ-Коми', 'РИТЭК', 'ЛУКОЙЛ-Калининградморнефть', 'все НГДО БС "ГиД"']
# company заполнилась успешно
# Текст из ячейки B1: currency_unit
# ['тонна', 'тысяча метров кубических', 'час', 'штука', 'метр кубический', 'единица измерения обеспечена аналитическим признаком', 'миллионная доля', 'процент', 'миллиграмм на кубический дециметр', 'грамм на тонну', '-', 'метров кубических на тонну', 'рубль', 'зависит от значения справочника "Оборудование, не входящее в сметы строек"', 'киловатт*час', 'сутки', 'бригада', 'зависит от значения справочника "Виды нефтепромыслового оборудования"', 'ремонты на бригаду', 'гигакалория', 'тысяча тонн на километр', 'тонн условного топлива', 'киловатт', 'тысяча киловатт*час', 'киловатт*час / тонна', 'грамм', 'килограмм условного топлива / тонна', 'килограмм условного топлива / гигакалория', 'грамм условного топлива / киловатт*час', 'килограмм условного топлива / тысяча метров кубических', 'мегакалория / тонна', 'гигакалория / тысяча метров кубических', 'гигакалория / тонна', 'киловатт*час / тысяча метров кубических', 'киловатт*час / тысяч тонн на километр', 'киловатт*час / миллион метров кубических на километр', 'киловатт*час / метр кубический', 'киловатт*час / гигакалория', 'Мкал/т', 'Мкал/тыс.м3', 'миллион метров кубических', 'скважина', 'тысяча тонн', 'Тонна', 'Тысяча метров кубических', 'тысяч метров кубических/тонн', 'тонна/сутки', 'Процент', 'станко-месяцы', 'метр', 'Сутки', 'погонный километр', 'километр квадратный', 'единиц', 'киловольт-ампер', 'километр', 'тысяча тонн/сутки', 'метр на станкомесяц']
# currency_unit заполнилась успешно
# Текст из ячейки C1: data_status
# ['План', 'Потребность', 'Факт']
# data_status заполнилась успешно
# Текст из ячейки D1: indicator_generation_method
# ['TBD', 'Автоматизированный', 'Нерелевантно для расчетного показателя', 'Ручной', 'Ручной (в части S/4HANA - Автоматизированный)']
# indicator_generation_method заполнилась успешно
# Текст из ячейки E1: keyfigure_category
# ['Базовый', 'Расчетный на лету', 'Расчетный с записью в ХД']
# keyfigure_category заполнилась успешно
# Текст из ячейки F1: load_time
# ['Год', 'День', 'Квартал', 'Месяц', 'Полугодие']
# load_time заполнилась успешно
# Текст из ячейки G1: method_of_obtaining
# ['Сумма', 'Сумма значений показателя/Кол-во значений показателя в расчете', 'Суммарное количество нефти/Суммарное количество меркаптанов', 'Суммарное количество нефти/Суммарное количество сероводоода', 'Суммарное количество нефти/Суммарное количество воды', 'Суммарное количество нефти/Суммарное количество мелких примесей', 'Суммарное количество нефти/Суммарное количество хлористых солей', 'Суммарное количество нефти/Суммарное количество хлорорганических соединений', 'Суммарное количество нефти/Суммарное количество общей серы', 'Сумма значений показателя/Сумма значений показателя', 'Общий процент', 'Сумма значений коэффициентов/Кол-во значений коэффициентов в расчете']
# method_of_obtaining заполнилась успешно
# Текст из ячейки H1: source_system
# ['OIS Lite', 'OIS УСОИ', 'Xls-модель Производственное планирование', 'Ручной ввод в BW/4HANA (ФВ.39)', 'ИСУ НГДО (BW)', 'Нерелевантно для НГДО', 'S/4HANA', 'Xls-модель Показатели Бухг. Систем', 'Ручной ввод в BW/4HANA (ФВ.08)', 'Ручной ввод в BW/4HANA (ФВ.09)', 'OIS+', 'Xls-модель Использование Реагентов', 'Ручной ввод в BW/4HANA', 'Нерелевантно для расчетного показателя', 'Ручной ввод в BW/4HANA (ФВ.11)', 'Xls-модель Экономическое планирование', 'Ручной ввод в BW/4HANA (ФВ.12)', 'Ручной ввод в BW/4HANA (ФВ.13)', 'Ранее показатель не формировался в текущем ОХД', 'Нерелевантно для показателя релиза 2', 'Ручной ввод в BW/4HANA (ФВ.15)', 'Ручной ввод в BW/4HANA (ФВ.22)', 'Ручной ввод в BW/4HANA (ФВ.34)', 'Xls-модель Строительство', 'Ручной ввод в BW/4HANA (ФВ.36)', 'Xls-модель Производственные показатели', 'Xls-модель ОНСС', 'Xls-модель Инвестиционное планирование', 'ССОО', 'Ручной ввод в BW/4HANA (ФВ.06)', 'Ручной ввод в BW/4HANA (ФВ.31)', 'Ручной ввод в BW/4HANA (ФВ.16)', 'OIS +', 'OIS Ремонты', 'НБ', 'Xls-модель Нефтепромысловое Оборудование', 'S/4HANA (для планирования годовой потребности Xls-модель Экономическое планирование)', 'S/4HANA (для планирования годовой потребности - НБ)', 'OIS iField', 'Xls-модель Аварии', 'АППиККП', 'Xls-модель Бурение', 'OIS Исследования', 'ИС ГРР', 'УГРР', 'Xls-модель Геологоразведочные работы', 'Ручной ввод в BW/4HANA (ФВ.01) (в части УКП)_x000D_\nXls-модель Инвестиционное планирование (в части Строительства скважин)', 'Ручной ввод в BW/4HANA (ФВ.01)', 'БС 21ФИП', 'Ручной ввод в BW/4HANA (ФВ.28)', 'Xls-модель Экономическое планирование, ИСУ НГДО (BW)', 'Ручной ввод в BW/4HANA (ФВ.01) (в части УКП)_x000D_\nXls-модель Экономическое планирование (в части Строительства скважин)', 'Ручной ввод в BW/4HANA (ФВ.32)', 'Ручной ввод в BW/4HANA (ФВ.04)', 'Ручной ввод в BW/4HANA (ФВ.30)', 'Ручной ввод в BW/4HANA (ФВ.33)', 'Ручной ввод в BW/4HANA (ФВ.05)', 'Xls-модель Энергетика', 'Ручной ввод в BW/4HANA (ФВ.29)', 'Ручной ввод в BW/4HANA (ФВ.03)', 'Ручной ввод в BW/4HANA (ФВ.02)', 'Ручной ввод в BW/4HANA (ФВ.07)', 'Ручной ввод в BW/4HANA (ФВ.17)', 'OIS Lite, ИСОХО', 'Ручной ввод в BW/4HANA (ФВ.18)', 'Ручной ввод в BW/4HANA (ФВ.19)', 'Ручной ввод в BW/4HANA (ФВ.20)', 'Ручной ввод в BW/4HANA (ФВ.21)', 'Ручной ввод в BW/4HANA (ФВ.27)', 'Xls-модель Добыча УВС и ТРИЗ нефти', 'Xls-модель Льготная ставка по ТП', 'Xls-модель Фактически понесенные инвестиции', 'OIS Pipe', 'Ручной ввод в BW/4HANA (ФВ.38)', 'Ручной ввод в BW/4HANA (ФВ.37)', 'Ручной ввод в BW/4HANA (ФВ.24)', 'Ручной ввод в BW/4HANA (ФВ.25)', 'Требует уточнения на следующем этапе проработки Модели данных']
# source_system заполнилась успешно
# Текст из ячейки I1: upload_deadline
# ['По запросу', 'Сутки']
# upload_deadline заполнилась успешно
# Текст из ячейки J1: value_type
# ['Количество', 'Сумма']
# value_type заполнилась успешно
# Текст из ячейки K1: analytical_feature
# ['Временная гранулярность', 'Международные проекты', 'Наименование НГДО', 'Виды скважин по продукту добычи/закачки', 'Статус данных', 'Производственные структурные подразделения', 'Категории источников ресурсов', 'Виды использования продукта на прочие нужды организации', 'Индикатор сдачи через УУН', 'Классификация по объему инвестиций', 'Реестр ОБКСиР', 'Направления инвестирования в строительство и в прочие проекты', 'Инвестиционные проекты', 'Статьи инвестиционных расходов', 'Единица измерения', 'Тип тепловой установки', 'Способы эксплуатации скважин', 'Цели закачки', 'Виды использования сырья в переработке', 'Сырье и товары газопереработки', 'Направления расхода энергии', 'Агрегат ЭС', 'Вид топлива ЭС', 'Режим работы агрегата электростанции по виду эксплуатации', 'Режим работы агрегата электростанции по подключению', 'Сервисная организация', 'Эксплуатирующая организация', 'Местонахождение остатков сырья и готовой продукции', 'Назначение скважины', 'Индикатор учета ремонта при расчете МРП', 'Месторождения', 'Географическая принадлежность', 'Регионы', 'Срок эксплуатации трубопровода', 'Промысловые мощности', 'Узлы учета нефти', 'СПП-элементы', 'Кредиторы (поставщики/подрядчики)', 'Дебиторы', 'Виды остатков нефти', 'Индикатор транспортировки через АК Транснефть', 'Категории потребителей', 'Региональные рынки', 'Направления поставки', 'Виды технологических установок по производству нефтепродуктов', 'Виды расходов продукта на собственные нужды (внутренний оборот)', 'Системы газопроводного транспорта', 'Типы ремонтных работ на скважине', 'Оборудование, не входящее в сметы строек', 'Целевое назначение приобретения оборудования', 'Виды нефтепромыслового оборудования', 'Виды работ по ремонту оборудования', 'Тип исполнителя работ', 'Место возникновения затрат', 'Реагенты для добычи нефти и газа', 'Классификатор вспомогательных материалов', 'Виды потерь продукта (внутренний оборот)', 'Компрессорные станции', 'Виды ремонтных работ на скважине', 'Виды источников финансирования', 'Виды геологоразведочных работ', 'Наименование лицензионного участка', 'Геологические структуры', 'Виды глубокого бурения при ГРР', 'Группы технологий ПНП', 'Направления затрат (ПНП)', 'Индикатор ОПР', 'Группировка исслед-й по связи с мероприятиями на фонде скв.', 'Виды исследований скважин', 'Индикатор проведения ГИС', 'Состояние скважины', 'Вид профиля ствола скважины', 'Виды скважин по этапу сдачи', 'Виды работ по бурению скважин', 'Валюта', 'Версии инвест. планирования', 'Инвестиционные мероприятия', 'Индикатор текущего года', 'Индикатор ликвидации скважины', 'Виды движения фонда скважин', 'Группы причин простоя скважин', 'Консолидированные группы предприятий', 'Интервалы дебита нефти', 'Индикатор импортного оборудования', 'Причина остановки', 'Интервалы наработки на отказ', 'Результаты испытаний поисково-разведочных скважин', 'Состояния скважины в процессе строительства', 'Формы заключения договоров', 'Формы оплаты', 'Этапы подготовки и строительства скважин', 'Текущее состояние работ по скважине', 'Причины отклонения сроков работ по ГРР', 'Индикатор типов закачиваемой в целях ППД воды', 'Состояние скважины по периоду ввода в эксплуатацию', 'Оборудование и материалы для строительства', 'Виды аварий и осложнений при строительстве скважин', 'Причины технологических инцидентов', 'Энергоресурсы', 'Группы мероприятий топливоэнергосбережения', 'Мероприятия топливоэнергосбережения', 'Индикатор принадлежности электросетей', 'Индикатор нарушений электроснабжения по вине ООО "Лукойл-Энергосети"', 'Группы простоев для ДН5', 'Индикатор разработки структуры', 'Индикатор периода выполнения мероприятия', 'Причины порывов трубопроводов', 'Вольтаж линий электропередач', 'Классификатор ГТМ на скважинах', 'Основание для движения фонда скважин', 'Дата движения фонда скважин', 'Срок договора по отчуждению скважин', 'Лицензии', 'Виды льготируемого УВС', 'Индексы пласта по гос.балансу', 'Виды нефти ТРИЗ', 'Виды несоответствий оборудования', 'Группы налога на дополнительный доход ( ...
# report_code заполнилась успешно
# Текст из ячейки O1: report_id
# ['AR-1', 'AR-2', 'AR-92', 'AR-115', 'AR-116', 'AR-122', 'AR-123', 'AR-128', 'AR-137', 'AR-138', 'AR-141', 'AR-143', 'AR-144', 'AR-147', 'AR-148', 'AR-150', 'AR-157', 'AR-158', 'AR-133', 'AR-134', 'AR-8', 'AR-9', 'AR-10', 'AR-11', 'AR-411', 'AR-15', 'AR-4', 'AR-415', 'AR-20', 'AR-37', 'AR-38', 'AR-39', 'AR-40', 'AR-41', 'AR-47', 'AR-48', 'AR-49', 'AR-61', 'AR-65', 'AR-55', 'AR-56', 'AR-57', 'AR-58', 'AR-59', 'AR-60', 'AR-87', 'AR-88', 'AR-90', 'FV_01.4', 'AR-5', 'AR-7', 'AR-409', 'AR-12', 'AR-13', 'AR-21', 'AR-412', 'AR-17', 'AR-16', 'AR-24', 'AR-25', 'AR-26', 'AR-27', 'AR-28', 'AR-29', 'AR-30', 'AR-31', 'AR-32', 'AR-33', 'AR-34', 'AR-35', 'AR-36', 'AR-42', 'AR-43', 'AR-44', 'AR-45', 'AR-46', 'AR-50', 'AR-51', 'AR-54', 'AR-62', 'AR-64', 'AR-63', 'AR-66', 'AR-67', 'AR-68', 'AR-69', 'AR-70', 'AR-71', 'AR-72', 'AR-74', 'AR-75', 'AR-76', 'AR-77', 'AR-78', 'AR-79', 'AR-80', 'AR-81', 'AR-82', 'AR-83', 'AR-84', 'AR-86', 'AR-94', 'AR-113', 'AR-114', 'AR-117', 'AR-118', 'AR-119', 'AR-120', 'AR-121', 'AR-124', 'AR-125', 'AR-126', 'AR-127', 'AR-129', 'AR-130', 'AR-131', 'AR-132', 'AR-135', 'AR-136', 'AR-139', 'AR-140', 'AR-145', 'AR-146', 'AR-149', 'AR-151', 'AR-152', 'AR-153', 'AR-154', 'AR-155', 'AR-156', 'AR-159', 'AR-306', 'AR-308', 'AR-414', 'AR-19', 'AR-416', 'AR-14', 'AR-413', 'AR-18', 'AR-22', 'AR-3', 'AR-166', 'AR-410', 'AR-161', 'AR-165', 'AR-160', 'AR-167', 'AR-168', 'AR-162', 'AR-164', 'AR-163', 'AR-170', 'AR-169', 'AR-6', 'AR-171', 'FV_01.1', 'FV_01.2', 'FV_02', 'FV_03', 'FV_04', 'FV_05', 'FV_06', 'FV_07', 'FV_08', 'FV_09', 'FV_10', 'FV_11', 'FV_12', 'FV_13', 'FV_14', 'FV_15', 'FV_16', 'FV_17', 'FV_18', 'FV_19', 'FV_20', 'FV_21', 'FV_22', 'FV_23', 'FV_24', 'FV_25', 'FV_26', 'FV_27', 'FV_28', 'FV_29', 'FV_30', 'FV_31', 'FV_32', 'FV_33', 'FV_34', 'FV_35', 'FV_36', 'FV_37', 'FV_38', 'FV_39', 'FV_40', 'FV_41', 'FV_42', 'FV_43', 'FV_44', 'FV_45', 'Аналитика ХД']
показатели по видам КРС на нагнетательном фонде скважин', '4.6 Показатели по видам ТРС', '4.7 Основные показатели работы бригад ТРС', '6.3 Сводная таблица по поисково-разведочному бурению (общество)', '6.4 Выполнение плана инвестиционных расходов на освоение природных ресурсов (на суше) (общество)', '6.5 Выполнение плана инвестиционных расходов на освоение природных ресурсов (на море) (общество)', '7.11 Динамика показателей бурения вторых стволов по НГДО, ТПП', '7.14 Затраты на геофизические исследования скважин', '7.4 Динамика показателей внедрения физических методов ПНП по НГДО, ТПП', '7.5 Динамика показателей внедрения химических методов повышения нефтеотдачи пластов по НГДО, ТПП', '7.6 Динамика показателей внедрения гидродинамических методов повышения нефтеотдачи пластов по НГДО, ТПП', '7.7 Динамика показателей внедрения тепловых методов повышения нефтеотдачи пластов по НГДО, ТПП', '7.8 Динамика показателей внедрения газовых методов повышения нефтеотдачи пластов по НГДО, ТПП', '7.9 Динамика показателей внедрения методов интенсификации добычи нефти по НГДО, ТПП', '9.13 Выполнение плана инвестиционных расходов по эксплуатационному бурению', '9.14 Выполнение плана инвестиционных расходов по поисково-разведочному бурению', '9.16 Выполнение плана инвестиционных расходов по бурению боковых стволов', 'Отчет по ФВ ОБКСИР КС', '1.7 Баланс добычи и сдачи нефти', '1.9 Выполнение плана инвестиционных расходов по оборудованию, не входящему в сметы строек под ввод новых скважин', '2.1 Добыча природного и использование попутного газа обществами Группы «ЛУКОЙЛ»', '2.2 Добыча и использование попутного газа по месторождениям', '2.6.8 Сведения о работе УПГ Зареченского м-я ТПП «РИТЭК-Самара-Нафта»', '2.5 Баланс добычи и поставки природного газа', '2.5.1 Баланс добычи и поставки природного газа (консолидация в разрезе организаций и ТПП, ЛОХЛ-попроектно)', '3.1 Со ...
# report_title заполнилась успешно
# Конец выполнения

# %% [markdown]
# Заполнение Keyfigure

# %%
def create_array():
    import pandas as pd

    # Замените 'your_excel_file.xlsx' на имя вашего файла Excel
    excel_file = 'KeyfigureFilling.xlsx'

    # Загрузите данные из Excel в DataFrame
    df = pd.read_excel(excel_file)

    # Преобразуйте DataFrame в массив массивов (список списков)
    data_as_list_of_lists = df.values.tolist()
    return data_as_list_of_lists



create_array()

# Замените параметрами подключения на ваши
conn_params = {
    'host': 'localhost',
    'database': 'rsm',
    'user': 'postgres',
    'password': 'postgres',
    'port': '5432'
}
import psycopg2
from psycopg2 import sql

# Замените 'your_table' на имя вашей таблицы в базе данных
table_name = 'keyfigure'

data_as_list_of_lists = create_array()
# Создайте соединение с базой данных
conn = psycopg2.connect(**conn_params)

# Создайте курсор для выполнения SQL-запросов
cursor = conn.cursor()

# Подготовьте SQL-запрос для вставки данных в таблицу
columns = ','.join(['sap_code', 'full_name', 'short_name', 'value_type_id', 'currency_unit_id', 'method_of_obtaining_id',
                    'keyfigure_category_id', 'load_time_id', 'upload_deadline_id', 
                    'data_status_id', 'formation_methodology',
                    'indicator_generation_method_id'])  # Замените на реальные названия столбцов
placeholders = ','.join(['%s' for _ in range(len(data_as_list_of_lists[0]))])
insert_query = sql.SQL(f"INSERT INTO {table_name} (sap_code, full_name, short_name, value_type_id, currency_unit_id, method_of_obtaining_id, keyfigure_category_id, load_time_id, upload_deadline_id, data_status_id, formation_methodology, indicator_generation_method_id) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)").format(sql.Identifier(table_name),sql.SQL(columns),sql.SQL(placeholders))

# Вставьте данные в таблицу
cursor.executemany(insert_query, data_as_list_of_lists)

# Сделайте коммит, чтобы изменения вступили в силу
conn.commit()

# Закройте курсор и соединение
cursor.close()
conn.close()

# %% [markdown]
# Заполнение еще 2 таблиц )))

# %%
conn = psycopg2.connect(
    dbname="rsm",
    user="postgres",
    password="postgres",
    host="localhost"
)

cur = conn.cursor()

df = pd.read_excel("indicator_source_system.xlsx")

for index, row in df.iterrows():
    # Получите название из Excel
    keyfigure = row['keyfigure_id']
    cur.execute("SELECT id FROM keyfigure WHERE sap_code = %s", (keyfigure,))
    result = cur.fetchone()

    company = row['company_id']
    cur.execute("SELECT id FROM company WHERE title = %s", (company,))
    result2 = cur.fetchone()

    source_system = row['source_system_id']
    cur.execute("SELECT id FROM source_system WHERE title = %s", (source_system,))
    result3 = cur.fetchone()

    if result and result2 and result3:
        # Если идентификатор найден, используйте его для вставки данных
        id_названия = result[0]
        id_company = result2[0]
        id_ss = result3[0]
        # Вставьте данные в вашу таблицу, заменив 'ваша_таблица' и 'столбцы' на соответствующие значения
        cur.execute(
            "INSERT INTO indicator_source_system (keyfigure_id, company_id, source_system_id) VALUES (%s, %s, %s)",
            (id_названия, id_company, id_ss))

# Не забудьте зафиксировать изменения и закрыть соединение
conn.commit()
cur.close()
conn.close()

# %% [markdown]
# Заполнение Report

# %%
# Замените параметрами подключения на ваши
conn_params = {
    'host': 'localhost',
    'database': 'rsm',
    'user': 'postgres',
    'password': 'postgres',
    'port': '5432'
}
file_path = 'report_filling.xlsx'
excel_file = file_path
df = pd.read_excel(excel_file)

# Замените 'your_table' на имя вашей таблицы в базе данных
table_name = 'report'

# Создайте соединение с базой данных
conn = psycopg2.connect(**conn_params)

# Создайте курсор для выполнения SQL-запросов
cursor = conn.cursor()

for index, row in df.iterrows():
    keyfigure = row['keyfigure_id']
    cursor.execute("SELECT id FROM keyfigure WHERE sap_code = %s", (keyfigure,))
    result = cursor.fetchone()

    if result:
        keyfig = result[0]
        # Подготовьте SQL-запрос для вставки данных в таблицу
        insert_query = sql.SQL(
            f"INSERT INTO {table_name} (report_indicator_id, report_code_id,report_id_id, report_title_id, business_process_id, formation_frequency_id,analytical_feature_id, data_status_id, keyfigure_category_id, keyfigure_id) "
            f"VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
        ).format(
            sql.Identifier(table_name)
        )

        # Вставьте данные в таблицу
        cursor.execute(insert_query, (
            row['report_indicator_id'], row['report_code_id'], row['report_id_id'], row['report_title_id'],
            row['business_process_id'], row['formation_frequency_id'], row['analytical_feature_id'],
            row['data_status_id'], row['keyfigure_category_id'], keyfig
        ))

# Сделайте коммит, чтобы изменения вступили в силу
conn.commit()

# Закройте курсор и соединение
cursor.close()
conn.close()
